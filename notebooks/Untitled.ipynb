# %%
import pandas as pd

# Fix 1: Use raw strings by adding 'r' prefix
oil = pd.read_csv(r"C:\Users\USER\Downloads\oil-usd-ngn-bank-returns-analysis\data/oil_prices.csv")
usd = pd.read_csv(r"C:\Users\USER\Downloads\oil-usd-ngn-bank-returns-analysis\data/usd_ngn.csv")


print(oil.head())
print(oil.tail())
print(usd.head())
print(usd.tail())
# Out:
#         Price               Close                High                 Low  \
# 0      Ticker                BZ=F                BZ=F                BZ=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2014-01-02  107.77999877929688  111.31999969482422  107.69000244140625
# 3  2014-01-03  106.88999938964844  108.62000274658203  106.77999877929688
# 4  2014-01-06   106.7300033569336  107.94999694824219  106.58000183105469
#
#                  Open Volume
# 0                BZ=F   BZ=F
# 1                 NaN    NaN
# 2  110.80000305175781   5131
# 3  107.91999816894531   5641
# 4  107.04000091552734   7015
#            Price              Close               High                Low  \
# 2761  2024-12-23  72.62999725341797  73.37000274658203   71.9800033569336
# 2762  2024-12-24  73.58000183105469  73.80999755859375  72.77999877929688
# 2763  2024-12-26  73.26000213623047  74.18000030517578   72.9800033569336
# ...
